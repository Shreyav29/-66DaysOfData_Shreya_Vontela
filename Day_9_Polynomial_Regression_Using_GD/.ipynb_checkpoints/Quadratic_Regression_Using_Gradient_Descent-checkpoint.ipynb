# %%
# OLS from scratch using numpy 
import numpy as np

# %%
from sklearn.datasets import load_boston
dataset = load_boston()

# %%
dataset.data.shape
# Out:
# (506, 13)

# %%
dataset.target.shape
# Out:
# (506,)

# %%
X = dataset.data
y = dataset.target[:,np.newaxis]

# %%
dataset.target.shape
# Out:
# (506,)

# %%
y.shape
# Out:
# (506, 1)

# %%
X.shape
# Out:
# (506, 13)

# %%
from matplotlib import pyplot as plt

# %%
_ = plt.plot(X)

# %%
plt.plot(X)
plt.plot(y)

plt.show()

# %%
plt.plot(df)
# Out:
# [<matplotlib.lines.Line2D at 0x7fa2431ec810>,
#  <matplotlib.lines.Line2D at 0x7fa243216510>,
#  <matplotlib.lines.Line2D at 0x7fa2432ff6d0>,
#  <matplotlib.lines.Line2D at 0x7fa2432ff790>,
#  <matplotlib.lines.Line2D at 0x7fa2432ff850>,
#  <matplotlib.lines.Line2D at 0x7fa2432ff990>,
#  <matplotlib.lines.Line2D at 0x7fa2432ffa50>,
#  <matplotlib.lines.Line2D at 0x7fa2432ffb10>,
#  <matplotlib.lines.Line2D at 0x7fa2432ffbd0>,
#  <matplotlib.lines.Line2D at 0x7fa2432ff950>,
#  <matplotlib.lines.Line2D at 0x7fa2431f8050>,
#  <matplotlib.lines.Line2D at 0x7fa2432ffd50>,
#  <matplotlib.lines.Line2D at 0x7fa2432ffe10>,
#  <matplotlib.lines.Line2D at 0x7fa2432ffed0>]

# %%
import pandas as pd
df = pd.DataFrame(X, columns = [i for i in 'abcdefghijklm'])
df['target'] = y

# %%
df.corr()
# Out:
#                a         b         c         d         e         f         g  \
# a       1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# b      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# c       0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# d      -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# e       0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# f      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# g       0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# h      -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# i       0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# j       0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# k       0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# l      -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069 -0.273534
# m       0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.613808  0.602339
# target -0.388305  0.360445 -0.483725  0.175260 -0.427321  0.695360 -0.376955
#
#                h         i         j         k         l         m    target
# a      -0.379670  0.625505  0.582764  0.289946 -0.385064  0.455621 -0.388305
# b       0.664408 -0.311948 -0.314563 -0.391679  0.175520 -0.412995  0.360445
# c      -0.708027  0.595129  0.720760  0.383248 -0.356977  0.603800 -0.483725
# d      -0.099176 -0.007368 -0.035587 -0.121515  0.048788 -0.053929  0.175260
# e      -0.769230  0.611441  0.668023  0.188933 -0.380051  0.590879 -0.427321
# f       0.205246 -0.209847 -0.292048 -0.355501  0.128069 -0.613808  0.695360
# g      -0.747881  0.456022  0.506456  0.261515 -0.273534  0.602339 -0.376955
# h       1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.496996  0.249929
# i      -0.494588  1.000000  0.910228  0.464741 -0.444413  0.488676 -0.381626
# j      -0.534432  0.910228  1.000000  0.460853 -0.441808  0.543993 -0.468536
# k      -0.232471  0.464741  0.460853  1.000000 -0.177383  0.374044 -0.507787
# l       0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.366087  0.333461
# m      -0.496996  0.488676  0.543993  0.374044 -0.366087  1.000000 -0.737663
# target  0.249929 -0.381626 -0.468536 -0.507787  0.333461 -0.737663  1.000000

# %%
df[['m','target']].corr()
# Out:
#                m    target
# m       1.000000 -0.737663
# target -0.737663  1.000000

# %%
X = df['m'][:,np.newaxis]

# %%
y = df['target'][:,np.newaxis]

# %%
plt.scatter(X,y)

# %%
X.shape, y.shape
# Out:
# ((506, 1), (506, 1))

# %% [markdown]
# # Linear regression with one variable

# %%
# Mean squared error loss function 
def cost_func(X,y,weights):
    y_pred = np.dot(X,weights)
    n = len(y)
    cost = np.sum((y_pred - y)**2)/(2*n)
    return cost

# %%
def gradient_descent(X,y,weights, learning_rate, iterations):
    n = len(y)
    cost_hist = np.zeros((iterations,1))
    
    for i in range(iterations):
        # weights = weights -  learning rate * d(cost)/d(weights) 
        # d(cost)/d(weights) = X(X*weights - y)/n ....do the calculations to check. 
        
        weights = weights - learning_rate * (X.T @ (X @ weights - y))/n
        cost_hist[i] = cost_func(X,y,weights)
        
    return cost_hist, weights

# %%
#Normalising the values

n = len(y)
mean = np.mean(X,axis = 0 )
sigma = np.std(X,axis = 0)

X = (X-mean)/sigma

X.shape
# Out:
# (506, 1)

# %%
np.mean(X,axis = 0 )
# Out:
# array([-3.08931624e-16])

# %%
#Adding 1s coluimn so that the constant can also be counted in X 
X = np.hstack((np.ones((n,1)),X))

# %%
X.shape
# Out:
# (506, 2)

# %%
n_features = X.shape[1]

# %%
n_features
# Out:
# 2

# %%
#You need to initialise weights to a random value. 
weights = np.zeros((n_features,1))
weights.shape
# Out:
# (2, 1)

# %%
#Actual function 

iterations = 1500
learning_rate = 0.01

initial_cost = cost_func(X,y,weights)
initial_cost
# Out:
# 296.0734584980237

# %%
cost_hist , ideal_weights = gradient_descent(X,y,weights,learning_rate,iterations)
ideal_weights
# Out:
# array([[22.53279993],
#        [-6.77765172]])

# %%
cost_hist
# Out:
# array([[290.5645022 ],
#        [285.16517413],
#        [279.87329269],
#        ...,
#        [ 19.24148361],
#        [ 19.24148361],
#        [ 19.24148361]])

# %%
import matplotlib.pyplot as plt
plt.plot(range(len(cost_hist)) , cost_hist)
plt.xlabel("Number of iterations") 
plt.ylabel("Cost function ")

plt.title("Convergence of the cost function ")
plt.show()

# %%
#Predicting the results 

y_pred = X @ ideal_weights

# %%
# Measuring accuracy or R2 of the test 
R2_linear = np.sum((y_pred - np.mean(y))**2)/np.sum((y - np.mean(y))**2)
R2_linear
# Out:
# 0.5441459888863384

# %%
#Mean squared error : 
MSE_linear = cost_hist[-1]
MSE_linear
# Out:
# array([19.24148361])

# %% [markdown]
# # Now performing Quadratic regression

# %%
df['m2'] = df['m'] * df['m']
X = df['m'][:,np.newaxis]
y = df['target'][:,np.newaxis]

# %%
X2 = df['m2'][:,np.newaxis]

# %%
X = np.hstack((X,X2 ))

# %%
X
# Out:
# array([[ 4.98  , 24.8004],
#        [ 9.14  , 83.5396],
#        [ 4.03  , 16.2409],
#        ...,
#        [ 5.64  , 31.8096],
#        [ 6.48  , 41.9904],
#        [ 7.88  , 62.0944]])

# %%
#Normalising the values

n = len(y)
mean = np.mean(X,axis = 0 )
sigma = np.std(X,axis = 0)

X = (X-mean)/sigma

X.shape
# Out:
# (506, 2)

# %%
X = np.hstack((np.ones((n,1)),X))

# %%
X
# Out:
# array([[ 1.        , -1.0755623 , -0.78952949],
#        [ 1.        , -0.49243937, -0.54045362],
#        [ 1.        , -1.2087274 , -0.82582493],
#        ...,
#        [ 1.        , -0.98304761, -0.7598079 ],
#        [ 1.        , -0.86530163, -0.71663755],
#        [ 1.        , -0.66905833, -0.63138918]])

# %%
#You need to initialise weights to a random value. 
weights = np.zeros((X.shape[1],1))
weights.shape
# Out:
# (3, 1)

# %%
#Actual function 

iterations = 1500
learning_rate = 0.01

initial_cost = cost_func(X,y,weights)
initial_cost
# Out:
# 296.0734584980237

# %%
cost_hist , ideal_weights = gradient_descent(X,y,weights,learning_rate,iterations)
ideal_weights
# Out:
# array([[22.53279993],
#        [-9.19472072],
#        [ 2.82197061]])

# %%
import matplotlib.pyplot as plt
plt.plot(range(len(cost_hist)) , cost_hist)
plt.xlabel("Number of iterations") 
plt.ylabel("Cost function ")

plt.title("Convergence of the cost function ")
plt.show()

# %%
cost_hist
# Out:
# array([[290.24306439],
#        [284.54321589],
#        [278.97074724],
#        ...,
#        [ 17.3556385 ],
#        [ 17.35391162],
#        [ 17.35218611]])

# %%
#Predicting the results 

y_pred = X @ ideal_weights
# Measuring accuracy or R2 of the test 
R2_quad = np.sum((y_pred - np.mean(y))**2)/np.sum((y - np.mean(y))**2)
R2_quad
# Out:
# 0.5053095441967927

# %%
#Mean squared error : 
MSE_quad = cost_hist[-1]
MSE_quad
# Out:
# array([17.35218611])
